# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelinaXYZ/c-cpp_gitpod_ex1/blob/master/10508%E5%BC%B5%E5%BF%83%E7%91%9C(%E8%87%BA%E5%8C%97%E5%B8%82%E8%A1%97%E9%A0%AD%E9%9A%A8%E6%A9%9F%E6%90%B6%E5%A5%AA%E6%A1%88%E4%BB%B6%E9%BB%9E%E4%BD%8D).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
	import requests
data=requests.get('https://data.taipei/api/v1/dataset/6ecb4c41-fbc9-4b04-b182-a7da6c780f8d?scope=resourceAquire')
print (data.text)
dict1=eval(data.text)
# Out:
# {"result":{"limit":1000,"offset":0,"count":32,"sort":"","results":[{"﻿編號":"1","案類":"搶奪","發生地點":"台北市中山區新生北路3段56巷","備註":"","發生日期":"1070209","發生時段":"02~04","_id":1},{"﻿編號":"2","案類":"搶奪","發生地點":"台北市北投區關渡里知行路316巷22弄1~30號","備註":"","發生日期":"1070313","發生時段":"18~20","_id":2},{"﻿編號":"3","案類":"搶奪","發生地點":"台北市中正區富水里思源街與永春街口","備註":"","發生日期":"1070316","發生時段":"18~20","_id":3},{"﻿編號":"4","案類":"搶奪","發生地點":"台北市萬華區(桂林路與柳州街)","備註":"","發生日期":"1070519","發生時段":"00~02","_id":4},{"﻿編號":"5","案類":"搶奪","發生地點":"台北市北投區八仙里西安街2段(與公館路口)","備註":"","發生日期":"1070611","發生時段":"18~20","_id":5},{"﻿編號":"6","案類":"搶奪","發生地點":"台北市中山區林森北路511~540號","備註":"","發生日期":"1070706","發生時段":"00~02","_id":6},{"﻿編號":"7","案類":"搶奪","發生地點":"台北市內湖區康樂街1~30號","備註":"","發生日期":"1070730","發生時段":"20~22","_id":7},{"﻿編號":"8","案類":"搶奪","發生地點":"台北市士林區福佳里中正路211~240號","備註":"","發生日期":"1071118","發生時段":"04~06","_id":8},{"﻿編號":"9","案類":"搶奪","發生地點":"台北市大同區伊寧街75巷(伊寧街)","備註":"","發生日期":"1071227","發生時段":"12~14","_id":9},{"﻿編號":"10","案類":"搶奪","發生地點":"台北市中正區三愛里臨沂街59巷31~60
# ...

# %%
#單純顯示
for  num in dict1['result']['results']:
  print(num['發生地點']+','+num['發生日期']+'\n')
# Out:
# 台北市中山區新生北路3段56巷,1070209
#
# 台北市北投區關渡里知行路316巷22弄1~30號,1070313
#
# 台北市中正區富水里思源街與永春街口,1070316
#
# 台北市萬華區(桂林路與柳州街),1070519
#
# 台北市北投區八仙里西安街2段(與公館路口),1070611
#
# 台北市中山區林森北路511~540號,1070706
#
# 台北市內湖區康樂街1~30號,1070730
#
# 台北市士林區福佳里中正路211~240號,1071118
#
# 台北市大同區伊寧街75巷(伊寧街),1071227
#
# 台北市中正區三愛里臨沂街59巷31~60號,1080118
#
# 台北市萬華區環河南路2段5巷口巷,1080118
#
# 台北市中正區網溪里廈門街123巷(內),1080327
#
# 台北市中正區河堤里同安街紀州庵前2段,1080327
#
# 台北市萬華區成都路76巷口弄,1080430
#
# 台北市萬華區(華西街與桂林路口),1080802
#
# 台北市大同區哈密街59巷21弄,1080807
#
# 台北市信義區四維里虎林街70巷31~60號,1080826
#
# 台北市萬華區漢中街31~60號,1081205
#
# 台北市萬華區武昌街2段121~150號,1090210
#
# 台北市萬華區昆明街181~210號,1090216
#
# 台北市文山區景行里羅斯福路6段391~420號,1090223
#
# 台北市大同區迪化街1段(永樂市場2號,1090416
#
# 台北市大安區龍安里和平東路1段199巷,1090422
#
# 台北市中山區中山北路2段與錦西街口,1090822
#
# 台北市萬華區梧州街與廣州街口,1090927
#
# 台北市大同區延平北路2段151~180號,1091106
#
# 台北市萬華區梧州街31~60號,1091124
#
# 台北市中山區建國北路三段75巷內,1100328
#
# 台北市士林區福安里延平北路7段107巷31~60號,1100504
#
# 台北市大同區延平北路2段247巷1~30號,1100617
#
# 台北市北投區中和里中和街441巷3弄1~30號,1100627
#
# 台北市大同區長安西路78巷4弄1~30號,1100924
